# %% [markdown]
# Create custom api key :https://www.exchangerate-api.com/docs/standard-requests

# %%
from sqlalchemy import create_engine

engine = create_engine('sqlite://', echo=False)

# %%
myapi = "861249c8cebf4f829fb19074"

# %%
import requests
import pandas as pd

url = f'https://v6.exchangerate-api.com/v6/{myapi}/latest/USD'
response = requests.get(url)
data = response.json()

# %% [markdown]
# ## JSON-dan dataframe

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       result                          documentation  \
# USD  success  https://www.exchangerate-api.com/docs
# AED  success  https://www.exchangerate-api.com/docs
# AFN  success  https://www.exchangerate-api.com/docs
# ALL  success  https://www.exchangerate-api.com/docs
# AMD  success  https://www.exchangerate-api.com/docs
# ..       ...                                    ...
# XPF  success  https://www.exchangerate-api.com/docs
# YER  success  https://www.exchangerate-api.com/docs
# ZAR  success  https://www.exchangerate-api.com/docs
# ZMW  success  https://www.exchangerate-api.com/docs
# ZWL  success  https://www.exchangerate-api.com/docs
#
#                                terms_of_use  time_last_update_unix  \
# USD  https://www.exchangerate-api.com/terms             1752364801
# AED  https://www.exchangerate-api.com/terms             1752364801
# AFN  https://www.exchangerate-api.com/terms             1752364801
# ...

# %%
df.isnull().sum()
# Out:
# result                   0
# documentation            0
# terms_of_use             0
# time_last_update_unix    0
# time_last_update_utc     0
# time_next_update_unix    0
# time_next_update_utc     0
# base_code                0
# conversion_rates         0
# dtype: int64

# %%
df.describe()
# Out:
#        time_last_update_unix  time_next_update_unix  conversion_rates
# count           1.630000e+02           1.630000e+02        163.000000
# mean            1.752365e+09           1.752451e+09       1931.887407
# std             0.000000e+00           0.000000e+00       8501.714591
# min             1.752365e+09           1.752451e+09          0.305600
# 25%             1.752365e+09           1.752451e+09          3.193300
# 50%             1.752365e+09           1.752451e+09         23.687100
# 75%             1.752365e+09           1.752451e+09        204.817550
# max             1.752365e+09           1.752451e+09      89500.000000

# %%
df.to_sql('exchange_rate_usd.sql', con=engine, index=False)
# Out:
# 163
